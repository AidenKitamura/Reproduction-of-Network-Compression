# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/MyDrive/CV/Torch-Pruning/Torch-Pruning/examples/
# Out:
# /content/gdrive/MyDrive/CV/Torch-Pruning/Torch-Pruning/examples

# %%
# %run prune_resnet18_cifar10.py --mode test --round 1
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Load model from mobilev2_l1-round1.pth
# Number of Parameters: 1.6M
# Acc=0.9116
#
# Run time: 2.151 s

# %%
# %run prune_resnet18_cifar10.py --mode prune --round 1 --total_epochs 30 --step_size 20
# Out:
# Streaming output truncated to the last 5000 lines.
# --enumerate 173
# --enumerate 174
# --enumerate 175
# --enumerate 176
# --enumerate 177
# --enumerate 178
# --enumerate 179
# --enumerate 180
# --enumerate 181
# --enumerate 182
# --enumerate 183
# --enumerate 184
# --enumerate 185
# --enumerate 186
# --enumerate 187
# --enumerate 188
# --enumerate 189
# --enumerate 190
# --enumerate 191
# --enumerate 192
# --enumerate 193
# --enumerate 194
# --enumerate 195
# Epoch 4/30, Acc=0.7920
# --epoch 5
# 196
# --enumerate 0
# --enumerate 1
# --enumerate 2
# --enumerate 3
# --enumerate 4
# --enumerate 5
# --enumerate 6
# --enumerate 7
# --enumerate 8
# --enumerate 9
# --enumerate 10
# --enumerate 11
# --enumerate 12
# --enumerate 13
# --enumerate 14
# --enumerate 15
# --enumerate 16
# --enumerate 17
# --enumerate 18
# --enumerate 19
# --enumerate 20
# --enumerate 21
# --enumerate 22
# --enumerate 23
# --enumerate 24
# --enumerate 25
# --enumerate 26
# --enumerate 27
# --enumerate 28
# ...

# %% [markdown]
# # New Section

# %%
# %run test.py -i 1 --image cat.jpg
# Out:
# MobileNetV2(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Block(
#       (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
